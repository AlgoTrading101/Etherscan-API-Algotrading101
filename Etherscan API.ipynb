# %%
import requests
import pandas as pd

# %% [markdown]
# # Ether Balance - single address

# %%
requests.get('https://api.etherscan.io/api?module=account&action=balance&address=0x4976a4a02f38326660d17bf34b431dc6e2eb2327&tag=latest&apikey=A1C15S3AXQHQ7PVVDX63VVK2IBAECS448Z').json()
# Out:
# {'status': '1', 'message': 'OK', 'result': '29724721687169089009293'}

# %% [markdown]
# # Normal Transactions List

# %%
data = requests.get('https://api.etherscan.io/api?module=account&action=txlist&address=0xddbd2b932c763ba5b1b7ae3b362eac3e8d40121a&startblock=0&endblock=99999999&page=1&offset=10&sort=asc&apikey=A1C15S3AXQHQ7PVVDX63VVK2IBAECS448Z').json()
data = pd.DataFrame(data['result'])
data.tail().T
# Out:
#                                                                    5  \
# blockNumber                                                   101773
# timeStamp                                                 1439827863
# hash               0x70bc1a43c9e80caae6b69fe845ba1567826413a8e42d...
# nonce                                                              5
# blockHash          0xe802363e95a7e4700058c64f308ff726eba63ec7a400...
# transactionIndex                                                   5
# from                      0x1a56a50c378d21d0aa544ed9a482300c7f6e78ec
# to                        0xddbd2b932c763ba5b1b7ae3b362eac3e8d40121a
# value                                        84512559000000000000000
# gas                                                            21000
# gasPrice                                                100000000000
# isError                                                            0
# txreceipt_status
# ...

# %% [markdown]
# # ERC20 Token transfer events

# %%
erc20 = pd.DataFrame(requests.get('https://api.etherscan.io/api?module=account&action=tokentx&contractaddress=0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2&address=0x4e83362442b8d1bec281594cea3050c8eb01311c&page=1&offset=100&startblock=0&endblock=27025780&sort=asc&apikey=A1C15S3AXQHQ7PVVDX63VVK2IBAECS448Z').json()['result'])
erc20.head().T
# Out:
#                                                                    0  \
# blockNumber                                                  4730207
# timeStamp                                                 1513240363
# hash               0xe8c208398bd5ae8e4c237658580db56a2a94dfa0ca38...
# nonce                                                            406
# blockHash          0x022c5e6a3d2487a8ccf8946a2ffb74938bf8e5c8a3f6...
# from                      0x642ae78fafbb8032da552d619ad43f1d81e4dd7c
# contractAddress           0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2
# to                        0x4e83362442b8d1bec281594cea3050c8eb01311c
# value                                         5901522149285533025181
# tokenName                                                      Maker
# tokenSymbol                                                      MKR
# tokenDecimal                                                      18
# transactionIndex                                                  81
# ...

# %% [markdown]
# # Contracts

# %%
requests.get('https://api.etherscan.io/api?module=contract&action=getabi&address=0xBB9bc244D798123fDe783fCc1C72d3Bb8C189413&apikey=A1C15S3AXQHQ7PVVDX63VVK2IBAECS448Z').json()['result']
# Out:
# '[{"constant":true,"inputs":[{"name":"","type":"uint256"}],"name":"proposals","outputs":[{"name":"recipient","type":"address"},{"name":"amount","type":"uint256"},{"name":"description","type":"string"},{"name":"votingDeadline","type":"uint256"},{"name":"open","type":"bool"},{"name":"proposalPassed","type":"bool"},{"name":"proposalHash","type":"bytes32"},{"name":"proposalDeposit","type":"uint256"},{"name":"newCurator","type":"bool"},{"name":"yea","type":"uint256"},{"name":"nay","type":"uint256"},{"name":"creator","type":"address"}],"type":"function"},{"constant":false,"inputs":[{"name":"_spender","type":"address"},{"name":"_amount","type":"uint256"}],"name":"approve","outputs":[{"name":"success","type":"bool"}],"type":"function"},{"constant":true,"inputs":[],"name":"minTokensToCreate","outputs":[{"name":"","type":"uint256"}],"type":"function"},{"constant":true,"inputs":[],"name":"rewardAccount","outputs":[{"name":"","type":"address"}],"type":"function"},{"constant":true,"inputs":[],"na
# ...

# %% [markdown]
# # Transactions

# %%
requests.get('https://api.etherscan.io/api?module=transaction&action=gettxreceiptstatus&txhash=0x513c1ba0bebf66436b5fed86ab668452b7805593c05073eb2d51d3a52f480a76&apikey=A1C15S3AXQHQ7PVVDX63VVK2IBAECS448Z').json()
# Out:
# {'status': '1', 'message': 'OK', 'result': {'status': '1'}}

# %% [markdown]
# # Block

# %%
requests.get('https://api.etherscan.io/api?module=block&action=getblockreward&blockno=2165403&apikey=A1C15S3AXQHQ7PVVDX63VVK2IBAECS448Z').json()
# Out:
# {'status': '1',
#  'message': 'OK',
#  'result': {'blockNumber': '2165403',
#   'timeStamp': '1472533979',
#   'blockMiner': '0x13a06d3dfe21e0db5c016c03ea7d2509f7f8d1e3',
#   'blockReward': '5314181600000000000',
#   'uncles': [{'miner': '0xbcdfc35b86bedf72f0cda046a3c16829a2ef41d1',
#     'unclePosition': '0',
#     'blockreward': '3750000000000000000'},
#    {'miner': '0x0d0c9855c722ff0c78f21e43aa275a5b8ea60dce',
#     'unclePosition': '1',
#     'blockreward': '3750000000000000000'}],
#   'uncleInclusionReward': '312500000000000000'}}

# %% [markdown]
# # Logs

# %%
logs = pd.DataFrame(requests.get('https://api.etherscan.io/api?module=logs&action=getLogs&fromBlock=379224&toBlock=latest&address=0x33990122638b9132ca29c723bdf037f1a891a70c&topic0=0xf63780e752c6a54a94fc52715dbc5518a3b4c3c2833d301a204226548a2a8545&apikey=A1C15S3AXQHQ7PVVDX63VVK2IBAECS448Z').json()['result'])
logs.tail().T
# Out:
#                                                                 364  \
# address                  0x33990122638b9132ca29c723bdf037f1a891a70c
# topics            [0xf63780e752c6a54a94fc52715dbc5518a3b4c3c2833...
# data
# blockNumber                                                0x17f0b1
# timeStamp                                                0x5742bd78
# gasPrice                                                0x4a817c800
# gasUsed                                                     0x107c2
# logIndex                                                         0x
# transactionHash   0x647676db70d8d17d4d59f27afcd048181f2dd0d6e20d...
# transactionIndex                                                 0x
#
#                                                                 365  \
# address                  0x33990122638b9132ca29c723bdf037f1a891a70c
# topics            [0xf63780e752c6a54a94fc52715dbc5518a3b4c3c2833...
# data
# ...

# %% [markdown]
# # GETH/Parity Proxy

# %%
requests.get('https://api.etherscan.io/api?module=proxy&action=eth_getStorageAt&address=0x6e03d9cce9d60f3e9f2597e13cd4c54c55330cfd&position=0x0&tag=latest&apikey=A1C15S3AXQHQ7PVVDX63VVK2IBAECS448Z').json()
# Out:
# {'jsonrpc': '2.0',
#  'id': 1,
#  'result': '0x0000000000000000000000003d0768da09ce77d25e2d998e6a7b6ed4b9116c2d'}

# %% [markdown]
# # Token data

# %%
requests.get('https://api.etherscan.io/api?module=stats&action=tokensupply&contractaddress=0x57d90b64a1a57749b0f932f1a3395792e12e7055&apikey=A1C15S3AXQHQ7PVVDX63VVK2IBAECS448Z').json()
# Out:
# {'status': '1', 'message': 'OK', 'result': '21265524714464'}

# %% [markdown]
# # Gas data

# %%
requests.get('https://api.etherscan.io/api?module=gastracker&action=gasestimate&gasprice=2000000000&apikey=A1C15S3AXQHQ7PVVDX63VVK2IBAECS448Z').json()
# Out:
# {'status': '1', 'message': 'OK', 'result': '3615'}

# %% [markdown]
# # Stats

# %%
requests.get('https://api.etherscan.io/api?module=stats&action=ethsupply2&apikey=A1C15S3AXQHQ7PVVDX63VVK2IBAECS448Z').json()
# Out:
# {'status': '1',
#  'message': 'OK',
#  'result': {'EthSupply': '118194367499000000000000000',
#   'Eth2Staking': '309618220365297000000000',
#   'BurntFees': '738514872810670998934509'}}
